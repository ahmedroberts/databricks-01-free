# %% [markdown]
# # 1st Databricks Notebook
# ---
#
# Ahmed is the 9th Raikage | 2026-04-05

# %%
print("Jumbo, Rafiki!\nMister Terrific is here.")

# %% [markdown]
# ## To make a successful git connection
# 1. created a repo on github
# 2. cloned it on databricks
# 3. had to install databricks on github
#
# This was my third iteration.

# %% [markdown]
# ## Testing out python querying with data bricks

# %%
df_01 = spark.table('orders')
display(df_01)

# %% [markdown]
# ## Testing out SQL querying files in volumes

# %%
# %sql
select * from csv.`/Volumes/workspace/default/youtubeseries`

# %%
# %sql
-- Could also use:
-- select * from `orders` limit 100;
select * from `workspace`.`default`.`orders` limit 100;

# %% [markdown]
# ## Google Drive + FiveTran
# 1. created a google drive
# 2. connected via FiveTran using our connectors
# 3. ran a query against synced data on the Google Drive

# %%
# %sql
select * from `workspace`.`google_drive`.`orderscsv` limit 100;
-- From the Google Drive via Five Tran
